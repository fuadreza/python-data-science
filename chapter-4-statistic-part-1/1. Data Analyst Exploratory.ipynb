# %% [markdown]
# # Data Analyst Exploratory

# %% [markdown]
# - Process to organizing, ploting, and to sum up a data set
# - Become a basic fondation to think about statistic

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv('2008_swing_states.csv')
df.head()
# Out:
#   state           county  total_votes  dem_votes  rep_votes  dem_share
# 0    PA      Erie County       127691      75775      50351      60.08
# 1    PA  Bradford County        25787      10306      15057      40.64
# 2    PA     Tioga County        17984       6390      11326      36.07
# 3    PA    McKean County        15947       6465       9224      41.21
# 4    PA    Potter County         7507       2300       5109      31.04

# %%
plt.style.use('fivethirtyeight')
# %matplotlib inline

# %%
plt.hist(df['dem_share'])
plt.xlabel('Count for Obama (%)')
plt.ylabel('Counties Total (District or City)')
# Out:
# Text(0, 0.5, 'Counties Total (District or City)')

# %%
plt.hist(df['dem_share'], bins=20)
plt.xlabel('Count for Obama (%)')
plt.ylabel('Counties Total (District or City)')
# Out:
# Text(0, 0.5, 'Counties Total (District or City)')

# %%
sns.set() # to set style as plt.style.use('seaborn')

# %%
plt.hist(df['dem_share'])
plt.xlabel('Count for Obama (%)')
plt.ylabel('Counties Total (District or City)')
# Out:
# Text(0, 0.5, 'Counties Total (District or City)')

# %% [markdown]
# ### If we use histogram there is still a bias acording to total of bin used

# %% [markdown]
# ## Bee Swarm Plot

# %%
sns.swarmplot(x='state', y='dem_share', data=df)
plt.xlabel('State')
plt.ylabel('Obama\'s total voice percentage')
# Out:
# Text(0, 0.5, "Obama's total voice percentage")

# %% [markdown]
# ## What if there are a lot of data?

# %%
all_df = pd.read_csv('2008_all_states.csv')

# %%
all_df.columns
# Out:
# Index(['state', 'county', 'total_votes', 'dem_votes', 'rep_votes',
#        'other_votes', 'dem_share', 'east_west'],
#       dtype='object')

# %%
sns.swarmplot(x='east_west', y='dem_share', data=all_df)
plt.xlabel('East or West')
plt.ylabel('Obama\'s total voice percentage')
# Out:
# Text(0, 0.5, "Obama's total voice percentage")

# %% [markdown]
# ## ECDF (Empirical Cumulative Distribution Function)

# %%
x = np.sort(df['dem_share'])
y = np.arange(1, len(x)+1) / len(x)

# %%
plt.plot(x, y, marker='.', linestyle='none')
plt.xlabel('Obama\'s total voice percentage')
plt.ylabel('ECDF')
plt.margins(0.02) # keeps data off plot edges

# %%
def ecdf(data):
    n = len(data)
    x = np.sort(data)
    y = np.arange(1, n+1) / n
    return x, y

# %%
data_pa = df[df['state'] == 'PA']['dem_share']
data_oh = df[df['state'] == 'OH']['dem_share']
data_fl = df[df['state'] == 'FL']['dem_share']

# %%
x_pa, y_pa = ecdf(data_pa)
x_oh, y_oh = ecdf(data_oh)
x_fl, y_fl = ecdf(data_fl)

# %%
plt.plot(x_pa, y_pa, marker='.', linestyle='none')
plt.plot(x_oh, y_oh, marker='.', linestyle='none')
plt.plot(x_fl, y_fl, marker='.', linestyle='none')
plt.xlabel('Obama\'s total voice percentage')
plt.ylabel('ECDF')
plt.legend(['PA', 'OH', 'FL'])
plt.margins(0.02) # keeps data off edges
